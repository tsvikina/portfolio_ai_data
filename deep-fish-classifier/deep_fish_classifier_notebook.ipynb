# %% [markdown]
# # Deep Fish Classifier
# A simple image classifier using FastAI and DuckDuckGo search.

# %%
# !pip install -U duckduckgo-search fastai python-slugify
# Out:
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.0.4-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: fastai in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.8.2)
# Collecting python-slugify
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: click>=8.1.8 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from duckduckgo-search) (8.2.1)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-0.15.0-cp38-abi3-win_amd64.whl.metadata (13 kB)
# Collecting lxml>=5.3.0 (from duckduckgo-search)
#   Downloading lxml-6.0.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: pip in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (25.1.1)
# Requirement already satisfied: packaging in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (24.2)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.9,>=1.8.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (1.8.2)
# Requirement already satisfied: fasttransform>=0.0.2 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (0.0.2)
# Requirement already satisfied: torchvision>=0.11 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (0.22.1)
# Requirement already satisfied: matplotlib in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (3.10.1)
# Requirement already satisfied: pandas in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (2.2.3)
# Requirement already satisfied: requests in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (2.32.3)
# Requirement already satisfied: pyyaml in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (6.0.2)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (11.2.1)
# Requirement already satisfied: scikit-learn in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (1.7.0)
# Requirement already satisfied: scipy in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (1.15.2)
# Requirement already satisfied: spacy<4 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (3.8.7)
# Requirement already satisfied: plum-dispatch in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (2.5.7)
# Requirement already satisfied: cloudpickle in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (3.1.1)
# Requirement already satisfied: torch<2.8,>=1.10 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastai) (2.7.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (2.2.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (2.11.5)
# Requirement already satisfied: jinja2 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (3.1.6)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from spacy<4->fastai) (65.5.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy<4->fastai) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->fastai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->fastai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->fastai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->fastai) (2025.1.31)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (0.1.5)
# Requirement already satisfied: filelock in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch<2.8,>=1.10->fastai) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch<2.8,>=1.10->fastai) (1.14.0)
# Requirement already satisfied: networkx in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch<2.8,>=1.10->fastai) (3.5)
# Requirement already satisfied: fsspec in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch<2.8,>=1.10->fastai) (2025.5.1)
# Requirement already satisfied: colorama in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4->fastai) (1.17.2)
# Collecting text-unidecode>=1.3 (from python-slugify)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy>=1.13.3->torch<2.8,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->spacy<4->fastai) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->fastai) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->fastai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->fastai) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->fastai) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->fastai) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->fastai) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->fastai) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->fastai) (2025.2)
# Requirement already satisfied: beartype>=0.16.2 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plum-dispatch->fastai) (0.21.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->fastai) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\teo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->fastai) (3.6.0)
# Downloading duckduckgo_search-8.0.4-py3-none-any.whl (18 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading lxml-6.0.0-cp311-cp311-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 2.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/4.0 MB 2.7 MB/s eta 0:00:02
#    --------------- ------------------------ 1.6/4.0 MB 2.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.4/4.0 MB 2.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 2.9 MB/s eta 0:00:00
# Downloading primp-0.15.0-cp38-abi3-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.1 MB 2.4 MB/s eta 0:00:02
#    ------------- -------------------------- 1.0/3.1 MB 3.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.8/3.1 MB 2.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.4/3.1 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------ --- 2.9/3.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 2.8 MB/s eta 0:00:00
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, python-slugify, primp, lxml, duckduckgo-search
#
#    ---------------- ----------------------- 2/5 [primp]
#    ---------------- ----------------------- 2/5 [primp]
#    ---------------- ----------------------- 2/5 [primp]
#    ------------------------ --------------- 3/5 [lxml]
#    ------------------------ --------------- 3/5 [lxml]
#    ------------------------ --------------- 3/5 [lxml]
#    ------------------------ --------------- 3/5 [lxml]
#    ------------------------ --------------- 3/5 [lxml]
#    ------------------------ --------------- 3/5 [lxml]
#    ------------------------ --------------- 3/5 [lxml]
#    -------------------------------- ------- 4/5 [duckduckgo-search]
#    ---------------------------------------- 5/5 [duckduckgo-search]
#
# Successfully installed duckduckgo-search-8.0.4 lxml-6.0.0 primp-0.15.0 python-slugify-8.0.4 text-unidecode-1.3

# %%
from duckduckgo_search import DDGS
from fastai.vision.all import *
from pathlib import Path
from slugify import slugify

# %%
def search_images_ddg(key, max_images=50):
    """Search for image URLs using DuckDuckGo."""
    try:
        with DDGS() as ddgs:
            return [r["image"] for r in ddgs.images(key, max_results=max_images) if r.get("image")]
    except Exception as e:
        print(f"Search failed for {key}: {e}")
        return []

# %%
categories = ['deep sea anglerfish',
    'gulper eel',
    'fangtooth fish',
    'viperfish',
    'black dragonfish']
path = Path('deep_fish')
path.mkdir(exist_ok=True)

for category in categories:
    print(f"Searching and downloading: {category}")
    dest = path/slugify(category)
    dest.mkdir(exist_ok=True, parents=True)
    results = search_images_ddg(category, max_images=50)
    download_images(dest, urls=results)
    verify_images(get_image_files(dest))
# Out:
# Searching and downloading: deep sea anglerfish
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# Searching and downloading: gulper eel
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# Searching and downloading: deep sea anglerfish
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# Searching and downloading: gulper eel
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# Searching and downloading: fangtooth fish
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# Searching and downloading: viperfish
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# Searching and downloading: black dragonfish
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)

# %%
# Clean corrupted images
failed = verify_images(get_image_files(path))
print(f"Found {len(failed)} corrupted images.")
failed.map(Path.unlink)
# Out:
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3570: UserWarning: image file could not be identified because AVIF support not installed
#   warnings.warn(message)
# Found 27 corrupted images.
# (#27) [None,None,None,None,None,None,None,None,None,None,None,None,None,None,None,None,None,None,None,None...]

# %%
# Optional: delete all images in each subfolder of deep_fish
def empty_folders(path):
    for folder in path.ls():
        if folder.is_dir():
            for img_file in folder.ls():
                img_file.unlink()
            print(f"Emptied folder: {folder.name}")

# Uncomment the line below to actually run the cleanup
# empty_folders(path)
# Out:
# Emptied folder: fangtooth-fish
# Emptied folder: viperfish
# Emptied folder: black-dragonfish
# Emptied folder: gulper-eel
# Emptied folder: deep-sea-anglerfish

# %%
import matplotlib.pyplot as plt

# %%
# Count images in each subfolder (i.e., class)
class_counts = {folder.name: len(get_image_files(folder)) for folder in path.ls() if folder.is_dir()}

# Print counts
for cls, count in class_counts.items():
    print(f"{cls}: {count} images")

# Plot
plt.figure(figsize=(8, 4))
plt.bar(class_counts.keys(), class_counts.values(), color='teal')
plt.title('Image Count per Class')
plt.ylabel('Number of Images')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# fangtooth-fish: 47 images
# viperfish: 44 images
# black-dragonfish: 40 images
# gulper-eel: 46 images
# deep-sea-anglerfish: 46 images

# %%
files = get_image_files(path/'gulper-eel')
for f in files[46:]:
    f.unlink()

# %%
files = get_image_files(path/'deep-sea-anglerfish')
for f in files[46:]:
    f.unlink()

# %%
dls = ImageDataLoaders.from_folder(
    path,
    train=".",
    valid_pct=0.2,
    seed=42,
    item_tfms=Resize(224),
    batch_tfms=aug_transforms()
)
dls.show_batch(max_n=6)

# %%
# Train a simple ResNet50 model
learn = vision_learner(dls, resnet50, metrics=accuracy)
learn.fine_tune(6)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.795835</td>
#       <td>1.780549</td>
#       <td>0.431818</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.512609</td>
#       <td>1.246472</td>
#       <td>0.477273</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.387319</td>
#       <td>0.828573</td>
#       <td>0.750000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.104202</td>
#       <td>0.614043</td>
#       <td>0.863636</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.947844</td>
#       <td>0.549015</td>
#       <td>0.886364</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.833176</td>
#       <td>0.490390</td>
#       <td>0.886364</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.741021</td>
#       <td>0.458805</td>
#       <td>0.909091</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##Using the image uploader and running predictions

# %%
# Interpretting the results:
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
interp.plot_top_losses(5, nrows=1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
img = PILImage.create('test-deep-sea-fish.png')
pred_class, pred_idx, probs = learn.predict(img)
print(f"Prediction: {pred_class} ({probs[pred_idx]:.2%})")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: viperfish (92.66%)

# %%
img = PILImage.create('test-deep-sea-fish-2.png')
pred_class, pred_idx, probs = learn.predict(img)
print(f"Prediction: {pred_class} ({probs[pred_idx]:.2%})")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: deep-sea-anglerfish (95.53%)

# %%
# Save the model
learn.export('deep_fish_classifier.pkl')
